# %%
# Import data/call library
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# Dataframe importation
FILENAME  = 'Descargas/covid19_tweets.csv'
df = pd.read_csv(FILENAME)

# %%
df
# Out:
#                            user_name         user_location  \
# 0                             ᏉᎥ☻լꂅϮ            astroworld
# 1                      Tom Basile 🇺🇸          New York, NY
# 2                    Time4fisticuffs      Pewee Valley, KY
# 3                        ethel mertz  Stuck in the Middle
# 4                           DIPR-J&K     Jammu and Kashmir
# ...                              ...                   ...
# 166651                         LynnZ                   NaN
# 166652  Public Health is the Economy         Sarasota, FL
# 166653           Farheen Qurashi, MD         Baltimore, MD
# 166654                  Alf O'Kenney          Montréal, QC
# 166655         J Michael 🇺🇸🏋🏼🏃🏼‍♂️🏝🚔           Connecticut
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...

# %%
df.dtypes
# Out:
# user_name           object
# user_location       object
# user_description    object
# user_created        object
# user_followers       int64
# user_friends         int64
# user_favourites      int64
# user_verified         bool
# date                object
# text                object
# hashtags            object
# source              object
# is_retweet            bool
# dtype: object

# %%
df = df['user_location'].value_counts()
print(df)
# Out:
# India                                3493
# United States                        2258
# New Delhi, India                     1627
# Mumbai, India                        1296
# Washington, DC                       1270
#                                      ...
# Makurdi/Kaduna                          1
# ferozpur                                1
# Secunderabad,Hyderabad                  1
# City of Brampton, Ontario, Canada       1
#  A Dub down the country, Irl            1
# Name: user_location, Length: 25656, dtype: int64

# %%
df = df.head(20)
print(df)
# Out:
# India               3493
# United States       2258
# New Delhi, India    1627
# Mumbai, India       1296
# Washington, DC      1270
# London, England     1216
# United Kingdom      1132
# London              1053
# New York, NY         993
# Australia            849
# Worldwide            808
# UK                   768
# Canada               765
# USA                  751
# New Delhi            749
# South Africa         739
# Los Angeles, CA      723
# Lagos, Nigeria       701
# WORLDWIDE            680
# California, USA      667
# Name: user_location, dtype: int64

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>
